# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nicole Clarke Medley**
#
# Sales

# %% [markdown]
# *I am interested in Data Science because I want to grow my business and use data to predict market trends*

# %% [markdown]
# ### My code in cell 5 is going to calculate the difference between 12 and 6

# %%
print(12 - 6)
# Out:
# 6

# %% [markdown]
# To-do List
# --------------------------------
#
# |Home | Business | Storage |
# |:---:|:---:|:---:|
# |1. Make pho|1. Track current inventory|1. Find moms clothes|
# |2. Clean bathroom | 2. Scan notes to pdfs| 2. Put up shelves|
# |3. Mop floors|3. Update spreadsheets| ~3. Close previous account~|
#
# ---
# Spreadsheets are found [Here](https://www.smartsheet.com/32-free-excel-spreadsheet-templates)
